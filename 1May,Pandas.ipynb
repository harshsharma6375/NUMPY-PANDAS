# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("C:\\Users\\Choud\\Downloads\\placement - placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.iloc[:4,:3]## iloc[row_range,column_range]
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3,["cgpa","placed"]]## iloc[row_range,column_range]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
df.size
# Out:
# 300

# %%
a=df.values
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df.shape
# Out:
# (100, 3)

# %%
df=df.copy()

# %%
p=df.sort_values(by="resume_score")
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r=df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df["cgpa"]=df["cgpa"].astype(int)
df ## change the datatype
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df["resume_score"]=df["resume_score"].astype(int)
df ## change the datatype
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
df["cgpa"]=df["cgpa"].add(4)
df ## change the datatype
# Out:
#     cgpa  resume_score  placed
# 0     12             6       1
# 1     10             5       0
# 2     12             8       1
# 3     10             7       1
# 4     11             7       1
# ..   ...           ...     ...
# 95    10             6       0
# 96    12             7       1
# 97    10             7       0
# 98    12             5       1
# 99    10             6       0
#
# [100 rows x 3 columns]

# %%
p
p["cgpa"]=p["cgpa"].add(4)
p ## change the datatype
# Out:
#      cgpa  resume_score  placed
# 94  12.01          4.95       1
# 87   9.62          5.05       0
# 13  12.50          5.09       1
# 41  12.68          5.15       1
# 1   10.17          5.17       0
# ..    ...           ...     ...
# 17  11.81          8.71       1
# 38  10.00          8.72       0
# 65  10.04          8.75       0
# 2   12.27          8.86       1
# 69  12.06          9.06       1
#
# [100 rows x 3 columns]

# %% [markdown]
# # p
# p["resume_score"]=p["resume_score"].add(6)
# p ## change the datatype

# %%
p.sort_index()
# Out:
#      cgpa  resume_score  placed
# 0   12.14         12.52       1
# 1   10.17         11.17       0
# 2   12.27         14.86       1
# 3   10.88         13.27       1
# 4   11.52         13.30       1
# ..    ...           ...     ...
# 95  10.33         12.38       0
# 96  12.23         13.76       1
# 97  10.65         13.78       0
# 98  12.14         11.63       1
# 99  10.09         12.61       0
#
# [100 rows x 3 columns]

# %%
mean=p["cgpa"].mean()
mean
# Out:
# 10.942199999999998

# %%
meadian=p["cgpa"].median()
meadian
# Out:
# 10.620000000000001

# %%
filter=p.filter(items=["cgpa","placed"])
filter
# Out:
#      cgpa  placed
# 94  12.01       1
# 87   9.62       0
# 13  12.50       1
# 41  12.68       1
# 1   10.17       0
# ..    ...     ...
# 17  11.81       1
# 38  10.00       0
# 65  10.04       0
# 2   12.27       1
# 69  12.06       1
#
# [100 rows x 2 columns]

# %%
p[["cgpa","placed"]]
# Out:
#      cgpa  placed
# 94  12.01       1
# 87   9.62       0
# 13  12.50       1
# 41  12.68       1
# 1   10.17       0
# ..    ...     ...
# 17  11.81       1
# 38  10.00       0
# 65  10.04       0
# 2   12.27       1
# 69  12.06       1
#
# [100 rows x 2 columns]

# %%
s=p.filter(items=[5,6],axis=0)
s
# Out:
#     cgpa  resume_score  placed
# 5  12.77         12.19       1
# 6   9.34         13.09       0

# %%
p.head(4)
# Out:
#      cgpa  resume_score  placed
# 94  12.01         10.95       1
# 87   9.62         11.05       0
# 13  12.50         11.09       1
# 41  12.68         11.15       1

# %%
p.loc[3:6,["cgpa","resume_score","placed"]]
# Out:
# Empty DataFrame
# Columns: [cgpa, resume_score, placed]
# Index: []

# %%
idx=p.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
lable=p.columns[0]
lable
# Out:
# 'cgpa'

# %%
d=p.rename(columns={"cgpa":"up_cgp",
                    "resume_score":"score"
    
})
d
# Out:
#     up_cgp  score  placed
# 94   12.01  10.95       1
# 87    9.62  11.05       0
# 13   12.50  11.09       1
# 41   12.68  11.15       1
# 1    10.17  11.17       0
# ..     ...    ...     ...
# 17   11.81  14.71       1
# 38   10.00  14.72       0
# 65   10.04  14.75       0
# 2    12.27  14.86       1
# 69   12.06  15.06       1
#
# [100 rows x 3 columns]

# %%
p.columns.tolist()
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
p
# Out:
#      cgpa  resume_score  placed
# 94  12.01         10.95       1
# 87   9.62         11.05       0
# 13  12.50         11.09       1
# 41  12.68         11.15       1
# 1   10.17         11.17       0
# ..    ...           ...     ...
# 17  11.81         14.71       1
# 38  10.00         14.72       0
# 65  10.04         14.75       0
# 2   12.27         14.86       1
# 69  12.06         15.06       1
#
# [100 rows x 3 columns]

# %%
p["Cgpa"]=p["cgpa"].astype(int)

# %%
p
# Out:
#      cgpa  resume_score  placed  Cgpa
# 94  12.01         10.95       1    12
# 87   9.62         11.05       0     9
# 13  12.50         11.09       1    12
# 41  12.68         11.15       1    12
# 1   10.17         11.17       0    10
# ..    ...           ...     ...   ...
# 17  11.81         14.71       1    11
# 38  10.00         14.72       0    10
# 65  10.04         14.75       0    10
# 2   12.27         14.86       1    12
# 69  12.06         15.06       1    12
#
# [100 rows x 4 columns]

# %%
a=p.drop(columns=["Cgpa"])

# %%
a
# Out:
#      cgpa  resume_score  placed
# 94  12.01         10.95       1
# 87   9.62         11.05       0
# 13  12.50         11.09       1
# 41  12.68         11.15       1
# 1   10.17         11.17       0
# ..    ...           ...     ...
# 17  11.81         14.71       1
# 38  10.00         14.72       0
# 65  10.04         14.75       0
# 2   12.27         14.86       1
# 69  12.06         15.06       1
#
# [100 rows x 3 columns]

# %%
p
# Out:
#      cgpa  resume_score  placed  Cgpa
# 94  12.01         10.95       1    12
# 87   9.62         11.05       0     9
# 13  12.50         11.09       1    12
# 41  12.68         11.15       1    12
# 1   10.17         11.17       0    10
# ..    ...           ...     ...   ...
# 17  11.81         14.71       1    11
# 38  10.00         14.72       0    10
# 65  10.04         14.75       0    10
# 2   12.27         14.86       1    12
# 69  12.06         15.06       1    12
#
# [100 rows x 4 columns]

# %%
df["new"]=p["cgpa"].where(p["cgpa"]>6,other=0)

# %%
df
# Out:
#     cgpa  resume_score  placed    new
# 0     16             6       1  12.14
# 1     14             5       0  10.17
# 2     16             8       1  12.27
# 3     14             7       1  10.88
# 4     15             7       1  11.52
# ..   ...           ...     ...    ...
# 95    14             6       0  10.33
# 96    16             7       1  12.23
# 97    14             7       0  10.65
# 98    16             5       1  12.14
# 99    14             6       0  10.09
#
# [100 rows x 4 columns]

# %%
## df mearging,contenating

# %%
data1={
    "name":["sally","mary","john"],
    "age":[50,40,30]
}
data2={
    "name":['sally',"peter","mick"],
    "age":[77,44,22]
}

# %%
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
df1
# Out:
#     name  age
# 0  sally   50
# 1   mary   40
# 2   john   30

# %%
df2
# Out:
#     name  age
# 0  sally   77
# 1  peter   44
# 2   mick   22

# %%
import pandas as pd
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Compare each column for common values
for col in df1.columns:
    common = set(df1[col]) & set(df2[col])
    print(f"Common in '{col}': {common}")
# Out:
# Common in 'Name': set()
# Common in 'Age': set()
# Common in 'Address': {'Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'}
# Common in 'Qualification': {'Msc', 'MCA', 'Phd', 'MA'}

# %%
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd

# %%
df2
# Out:
#      Name  Age    Address Qualification
# 0    Abhi   17     Nagpur           Msc
# 1  Ayushi   14     Kanpur            MA
# 2  Dhiraj   12  Allahabad           MCA
# 3  Hitesh   52    Kannuaj           Phd

# %%
new_dt=pd.concat([df1,df2])

# %%
df_common = pd.merge(df1, df2, on='Address', how='inner')
df_common
# Out:
#    Name_x  Age_x    Address Qualification_x  Name_y  Age_y Qualification_y
# 0     Jai     27     Nagpur             Msc    Abhi     17             Msc
# 1  Princi     24     Kanpur              MA  Ayushi     14              MA
# 2  Gaurav     22  Allahabad             MCA  Dhiraj     12             MCA
# 3    Anuj     32    Kannuaj             Phd  Hitesh     52             Phd
