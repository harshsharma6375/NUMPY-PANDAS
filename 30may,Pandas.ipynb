# %%
import numpy as np 
import pandas as pd

# %%
df =pd.read_csv("employees.csv")

# %%
df
# Out:
#    emp_id     name deprtement  salary
# 0       1     aman         it     200
# 1       2      sam       sles     100
# 2       3   aniket      sales     500
# 3       4  pallavi         it     200

# %%
df =pd.read_csv("C:\\Users\\Choud\\Downloads\\titanic - titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df =pd.read_csv("C:\\Users\\Choud\\Downloads\\titanic - titanic.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv("C:\\Users\\Choud\\Downloads\\titanic - titanic.csv")

# %%
df

# %% [markdown]
# ##  top 5 data

# %%
df.head(2)
# Out:
#    emp_id  name deprtement  salary
# 0       1  aman         it     200
# 1       2   sam       sles     100

# %%
df.head(10)
# Out:
#    emp_id     name deprtement  salary
# 0       1     aman         it     200
# 1       2      sam       sles     100
# 2       3   aniket      sales     500
# 3       4  pallavi         it     200

# %% [markdown]
# ## bottom 5 data

# %%
df.tail(2)
# Out:
#    emp_id     name deprtement  salary
# 2       3   aniket      sales     500
# 3       4  pallavi         it     200

# %%
df.tail(10)
# Out:
#    emp_id     name deprtement  salary
# 0       1     aman         it     200
# 1       2      sam       sles     100
# 2       3   aniket      sales     500
# 3       4  pallavi         it     200

# %% [markdown]
# ## ramdom index data

# %%
df.sample(4)
# Out:
#    emp_id     name deprtement  salary
# 0       1     aman         it     200
# 2       3   aniket      sales     500
# 3       4  pallavi         it     200
# 1       2      sam       sles     100

# %%
df = pd.read_csv("C://Users//Choud//Downloads/covid_toy - covid_toy.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv("C://Users//Choud//Downloads/covid_toy - covid_toy.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df

# %%
ds = pd.read_csv("C://Users//Choud//Downloads/placement - placement.csv")
ds

# %%
df.head(10)
# Out:
#    emp_id     name deprtement  salary
# 0       1     aman         it     200
# 1       2      sam       sles     100
# 2       3   aniket      sales     500
# 3       4  pallavi         it     200

# %%
df.tail(10)
# Out:
#    emp_id     name deprtement  salary
# 0       1     aman         it     200
# 1       2      sam       sles     100
# 2       3   aniket      sales     500
# 3       4  pallavi         it     200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      4 non-null      int64
#  1   name        4 non-null      object
#  2   deprtement  4 non-null      object
#  3   salary      4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes

# %%
df.describe()
# Out:
#          emp_id      salary
# count  4.000000    4.000000
# mean   2.500000  250.000000
# std    1.290994  173.205081
# min    1.000000  100.000000
# 25%    1.750000  175.000000
# 50%    2.500000  200.000000
# 75%    3.250000  275.000000
# max    4.000000  500.000000

# %%
df
# Out:
#    emp_id     name deprtement  salary
# 0       1     aman         it     200
# 1       2      sam       sles     100
# 2       3   aniket      sales     500
# 3       4  pallavi         it     200

# %%
tp=df.iloc[:4,:3]## iloc[row_range,column_range]
tp
# Out:
#    emp_id     name deprtement
# 0       1     aman         it
# 1       2      sam       sles
# 2       3   aniket      sales
# 3       4  pallavi         it

# %%
ts=df.loc[1:3,["name","deprtement"]]## iloc[row_range,column_range]
ts
# Out:
#       name deprtement
# 1      sam       sles
# 2   aniket      sales
# 3  pallavi         it

# %%
ts=df.empty
ts
# Out:
# False

# %%
df.isnull().sum() ## for check missing value
# Out:
# emp_id        0
# name          0
# deprtement    0
# salary        0
# dtype: int64

# %%
df.dropna() ## for removing missing values
# Out:
#    emp_id     name deprtement  salary
# 0       1     aman         it     200
# 1       2      sam       sles     100
# 2       3   aniket      sales     500
# 3       4  pallavi         it     200

# %%
i=df.ndim
i
# Out:
# 2

# %%
df = pd.read_csv("C://Users//Choud//Downloads/flipkart.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df = pd.read_csv("C://Users//Choud//Downloads/flipkart.csv")
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CGtC98 href  24 non-null     object
#  1   DByuf4 src   24 non-null     object
#  2   uu79Xy       24 non-null     object
#  3   KzDlHZ       24 non-null     object
#  4   XQDdHH       24 non-null     float64
#  5   Rza2QY src   24 non-null     object
#  6   Wphh3N       24 non-null     object
#  7   hG7V+4       24 non-null     object
#  8   Wphh3N 2     24 non-null     object
#  9   J+igdf       24 non-null     object
#  10  J+igdf 2     24 non-null     object
#  11  J+igdf 3     24 non-null     object
#  12  J+igdf 4     24 non-null     object
#  13  J+igdf 5     24 non-null     object
#  14  J+igdf 6     15 non-null     object
#  15  Nx9bqj       24 non-null     object
#  16  yRaY8j       23 non-null     object
#  17  UkUFwK       23 non-null     object
# ...

# %%
ds.describe()
# Out:
#           XQDdHH
# count  24.000000
# mean    4.554167
# std     0.072106
# min     4.400000
# 25%     4.500000
# 50%     4.550000
# 75%     4.600000
# max     4.700000

# %%
ds.tail()
# Out:
#                                           CGtC98 href  \
# 21  https://www.flipkart.com/vivo-x-fold3-pro-luna...
# 22  https://www.flipkart.com/apple-iphone-15-green...
# 23  https://www.flipkart.com/apple-iphone-16e-blac...
# 24                                                NaN
# 25                                                NaN
#
#                                            DByuf4 src          uu79Xy  \
# 21  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 22  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 23  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 24                                                NaN             NaN
# 25                                                NaN             NaN
#
#                                     KzDlHZ  XQDdHH  \
# 21  vivo X Fold3 Pro (Lunar White, 512 GB)     4.7
# 22         Apple iPhone 15 (Green, 256 GB)     4.6
# 23        Apple iPhone 16e (Black, 128 GB)     4.6
# ...

# %%
ds.head()
# Out:
#                                          CGtC98 href  \
# 0  https://www.flipkart.com/samsung-galaxy-s24-fe...
# 1  https://www.flipkart.com/samsung-galaxy-s24-5g...
# 2  https://www.flipkart.com/samsung-galaxy-s24-5g...
# 3  https://www.flipkart.com/samsung-galaxy-s24-5g...
# 4  https://www.flipkart.com/samsung-galaxy-s24-5g...
#
#                                           DByuf4 src          uu79Xy  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 1  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 2  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 3  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 4  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
#
#                                            KzDlHZ  XQDdHH  \
# 0         SAMSUNG Galaxy S24 FE 5G (Blue, 128 GB)     4.4
# 1     SAMSUNG Galaxy S24 5G (Marble Gray, 128 GB)     4.5
# ...
